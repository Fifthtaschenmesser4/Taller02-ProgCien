# %%
# !git clone https://github.com/Fifthtaschenmesser4/Taller02-ProgCien
# Out:
# Cloning into 'Taller02-ProgCien'...
# remote: Enumerating objects: 71, done.
# remote: Counting objects: 100% (71/71), done.
# remote: Compressing objects: 100% (60/60), done.
# remote: Total 71 (delta 18), reused 62 (delta 9), pack-reused 0 (from 0)
# Receiving objects: 100% (71/71), 1.46 MiB | 14.00 MiB/s, done.
# Resolving deltas: 100% (18/18), done.

# %%
import sys
sys.path.append('/content/Taller02-ProgCien')

import main

# %%
# !python ./Taller02-ProgCien/main.py

# %%
df = main.main()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_490/1966152403.py in <cell line: 0>()
# ----> 1 df = main.main()
#
# /content/Taller02-ProgCien/main.py in main()
#      78
#      79     #1. CARGAR DATOS EN Biblia
# ---> 80     df_raw = cargar_dataset(path_bible, path_key, path_genre)
#      81
#      82     biblia = Biblia.from_dataframe(
#
# /content/Taller02-ProgCien/main.py in cargar_dataset(path_bible, path_key, path_genre)
#      29     Carga CSV de descargado de Kaggle.
#      30     """
# ---> 31     df = pd.read_csv(path_bible)
#      32     """
#      33     columnas: id,b,c,v,t
#
# ...

# %%
df
# Out:
# <function main.main()>
